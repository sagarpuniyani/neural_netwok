# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarpuniyani/neural_netwok/blob/main/perceptron_weight_bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=100,hypercube=False,class_sep=10)

# %%
X.shape
# Out:
# (100, 2)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0] , X[:,1] , c=y , cmap='winter' , s=100 )

# %%
def perceptron(X,y):

  w1=w2=b=1
  lr = 0.1

  for i in range(1000):
    for j in range(X.shape[0]):

      # checking the condition
      z = w1*X[j][0] + w2*X[j][1] + b

      if z*y[j] < 0:
        w1 = w1 + lr*y[j]*X[j][0]
        w2 = w2 + lr*y[j]*X[j][1]
        b  = b  + lr*y[j]
  return w1 , w2 , b

# %%
w1 , w2 , b = perceptron(X , y)

# %%
m = -(w1/w2)
c = -(b /w2)

# %%
print(m)
print(c)
# Out:
# -3.4757022455219797
# -5.531708845010558

# %%
x_input = np.linspace(-3 ,3,100)
y_input = m*x_input + c

plt.figure(figsize=(10,6))
plt.plot(x_input , y_input , color='red' , linewidth=3)
plt.scatter(X[:,0] , X[:,1] , c=y , cmap='winter' , s=100 )

# %% [markdown]
# #### problem with perceptron

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['output']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['output']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['output']=[0,1,1,0]

# %%
or_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(x=or_data['input1'],y=or_data['input2'],hue=or_data['output'] , s=1000)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(x=and_data['input1'],y=and_data['input2'],hue=and_data['output'] , s=1000)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
xor_data
# Out:
#    input1  input2  output
# 0       1       1       0
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(x=xor_data['input1'],y=xor_data['input2'],hue=xor_data['output'] , s=1000)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(x=and_data['input1'],y=and_data['input2'],hue=and_data['output'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(x=or_data['input1'],y=or_data['input2'],hue=or_data['output'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
import xgboost as xgb

import matplotlib
matplotlib.use('Agg')
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

# %%
X = xor_data[['input1', 'input2']].values
y = xor_data['output'].values

# %%
import seaborn as sns
import xgboost as xgb
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

# Fit the XGBoost classifier
clf3 = xgb.XGBClassifier()
clf3.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron


# XOR dataset
xor_data = {
    'input1': [1, 1, 0, 0],
    'input2': [1, 0, 1, 0],
    'output': [0, 1, 1, 0]
}

X = np.array([xor_data['input1'], xor_data['input2']]).T
y = xor_data['output']

# Train your classifier (clf.fit(X, y))
clf4=Perceptron()
clf4.fit(X,y)

# Create a meshgrid
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Predict the labels
Z = clf1.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision regions using seaborn
sns.set()
plt.contourf(xx, yy, Z, alpha=0.8)
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette='winter', s=100)

# Add labels and title
plt.xlabel('Input 1')
plt.ylabel('Input 2')
plt.title('Decision Region Plot for XOR')

# Show the plot
plt.show()
